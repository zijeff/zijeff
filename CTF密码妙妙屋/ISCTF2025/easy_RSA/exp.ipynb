# %%
from Crypto.Util.number import *
from sage.all import xgcd

N = ...
ct1 = ...
ct2 = ...
e = 65537

e1 = e
e2 = N + 1  

g, u, v = xgcd(e1, e2)

print(g)
print(u*e1 + v*e2 == g)
ct2_inv = inverse(ct2, N)
m = pow(ct1, u, N) * pow(ct2_inv, -v, N) % N
print(m)
print(long_to_bytes(int(m)))
# Out:
# 1
# True
# 3176666995451249134434439822293588757184710260394558203398455337887666810874364351965384641608057148592089299798969635876057151869
# b'ISCTF{Congratulations_you_master_Mathematical_ability}'
